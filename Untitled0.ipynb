# %% [markdown]
# <a href="https://colab.research.google.com/github/bsiima/Code-Queens/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# The previous link was for the GitHub page (blob).
# To read the CSV directly, you need the 'raw' content link.
csv_url = "https://raw.githubusercontent.com/SarangPratap/Dataset/master/Encoding%20Data.csv"

df = pd.read_csv(csv_url)

# Displaying the top 10 results to verify
df.head(10)
# Out:
#    id bin_1 bin_2  nom_0 ord_2
# 0   0     F     N    Red   Hot
# 1   1     F     Y   Blue  Warm
# 2   2     F     N   Blue  Cold
# 3   3     F     N  Green  Warm
# 4   4     T     N    Red  Cold
# 5   5     T     N  Green   Hot
# 6   6     F     N    Red  Cold
# 7   7     T     N    Red  Cold
# 8   8     F     N   Blue  Warm
# 9   9     F     Y    Red   Hot

# %%
# you can always use simple mapping on binary features.
df['bin_1'] = df['bin_1'].apply(
    lambda x: 1 if x == 'T' else (0 if x == 'F' else None))
df['bin_2'] = df['bin_2'].apply(
    lambda x: 1 if x == 'Y' else (0 if x == 'N' else None))
sns.countplot(df['bin_1'])
sns.countplot(df['bin_2'])
# Out:
# <Axes: ylabel='count'>

# %%
# Out:
# DataFrame after binary encoding:
#    id  bin_1  bin_2  nom_0 ord_2
# 0   0      0      0    Red   Hot
# 1   1      0      1   Blue  Warm
# 2   2      0      0   Blue  Cold
# 3   3      0      0  Green  Warm
# 4   4      1      0    Red  Cold
# 5   5      1      0  Green   Hot
# 6   6      0      0    Red  Cold
# 7   7      1      0    Red  Cold
# 8   8      0      0   Blue  Warm
# 9   9      0      1    Red   Hot

# %%
df = pd.read_csv(csv_url)
ordinal_mapping = {
    'Cold': 0,
    'Warm': 1,
    'Hot': 2
}

df['ord_2'] = df['ord_2'].map(ordinal_mapping)

import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")

# Create a count plot to visualize the distribution of the newly encoded 'ord_2'
plt.figure(figsize=(6, 4))
sns.countplot(x=df['ord_2'])
plt.title('Count of ord_2 (Ordinal Encoded)')
plt.xlabel('Temperature Category (0=Cold, 1=Warm, 2=Hot)')
plt.ylabel('Count')
plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
df = pd.read_csv(csv_url)
df.head(10)
# transforming the column after fitting
enc = enc.fit_transform(df[['nom_0']]).toarray()
# converting arrays to a dataframe
encoded_colm = pd.DataFrame(enc)
# concatenating dataframes
df = pd.concat([df, encoded_colm], axis=1)
# removing the encoded column.


df = df.drop(['nom_0'], axis=1)
df.head(10)
# Out:
#    id bin_1 bin_2 ord_2    0    1    2
# 0   0     F     N   Hot  0.0  0.0  1.0
# 1   1     F     Y  Warm  1.0  0.0  0.0
# 2   2     F     N  Cold  1.0  0.0  0.0
# 3   3     F     N  Warm  0.0  1.0  0.0
# 4   4     T     N  Cold  0.0  0.0  1.0
# 5   5     T     N   Hot  0.0  1.0  0.0
# 6   6     F     N  Cold  0.0  0.0  1.0
# 7   7     T     N  Cold  0.0  0.0  1.0
# 8   8     F     N  Warm  1.0  0.0  0.0
# 9   9     F     Y   Hot  0.0  0.0  1.0

# %%
df=pd.read_csv(csv_url)
# grouping by frequency
fq = df.groupby('nom_0').size()/len(df)
# mapping values to dataframe
df.loc[:, "{}_freq_encode".format('nom_0')] = df['nom_0'].map(fq)
# drop original column.
df = df.drop(['nom_0'], axis=1)
fq.plot.bar(stacked=True)
df.head(10)
# Out:
#    id bin_1 bin_2 ord_2  nom_0_freq_encode
# 0   0     F     N   Hot                0.5
# 1   1     F     Y  Warm                0.3
# 2   2     F     N  Cold                0.3
# 3   3     F     N  Warm                0.2
# 4   4     T     N  Cold                0.5
# 5   5     T     N   Hot                0.2
# 6   6     F     N  Cold                0.5
# 7   7     T     N  Cold                0.5
# 8   8     F     N  Warm                0.3
# 9   9     F     Y   Hot                0.5

# %%
df=pd.read_csv(csv_url)
from sklearn.preprocessing import OrdinalEncoder
ord1 = OrdinalEncoder()
# fitting encoder
ord1.fit([df['ord_2']])
# transforming the column after fitting
df["ord_2"] = ord1.transform(df[["ord_2"]])
df.head(10)
# Out:
#    id bin_1 bin_2  nom_0  ord_2
# 0   0     F     N    Red    1.0
# 1   1     F     Y   Blue    2.0
# 2   2     F     N   Blue    0.0
# 3   3     F     N  Green    2.0
# 4   4     T     N    Red    0.0
# 5   5     T     N  Green    1.0
# 6   6     F     N    Red    0.0
# 7   7     T     N    Red    0.0
# 8   8     F     N   Blue    2.0
# 9   9     F     Y    Red    1.0

# %% [markdown]
# # grouping by frequency
# fq = df.groupby('nom_0').size()/len(df)
# # mapping values to dataframe
# df.loc[:, "{}_freq_encode".format('nom_0')] = df['nom_0'].map(fq)
# # drop original column.
#
# fq.plot.bar(stacked=True)
# df.head(10)

# %%
# grouping by frequency
df=pd.read_csv(csv_url)
fq = df.groupby('nom_0').size()/len(df)
# mapping values to dataframe
df.loc[:, "{}_freq_encode".format('nom_0')] = df['nom_0'].map(fq)
# drop original column.
df = df.drop(['nom_0'], axis=1)
fq.plot.bar(stacked=True)
df.head(10)
# Out:
#    id bin_1 bin_2 ord_2  nom_0_freq_encode
# 0   0     F     N   Hot                0.5
# 1   1     F     Y  Warm                0.3
# 2   2     F     N  Cold                0.3
# 3   3     F     N  Warm                0.2
# 4   4     T     N  Cold                0.5
# 5   5     T     N   Hot                0.2
# 6   6     F     N  Cold                0.5
# 7   7     T     N  Cold                0.5
# 8   8     F     N  Warm                0.3
# 9   9     F     Y   Hot                0.5

# %%
df=pd.read_csv(csv_url)
from sklearn.preprocessing import OrdinalEncoder
ord1 = OrdinalEncoder()
# fitting encoder
ord1.fit(df[['ord_2']])
# transforming the column after fitting
df["ord_2"] = ord1.transform(df[["ord_2"]])
df.head(10)
# Out:
#    id bin_1 bin_2  nom_0  ord_2
# 0   0     F     N    Red    1.0
# 1   1     F     Y   Blue    2.0
# 2   2     F     N   Blue    0.0
# 3   3     F     N  Green    2.0
# 4   4     T     N    Red    0.0
# 5   5     T     N  Green    1.0
# 6   6     F     N    Red    0.0
# 7   7     T     N    Red    0.0
# 8   8     F     N   Blue    2.0
# 9   9     F     Y    Red    1.0

# %% [markdown]
# BINARY ENCODING

# %%
# !pip install category_encoders
from category_encoders import BinaryEncoder
df=pd.read_csv(csv_url)
# creating instance of binary encoder
encoder = BinaryEncoder(cols =['ord_2'])
# transforming the column after fitting
newdata = encoder.fit_transform(df['ord_2'])
# concatenating dataframe
df = pd.concat([df, newdata], axis = 1)
# dropping old column
df = df.drop(['ord_2'], axis = 1)
df.head(10)
# Out:
# ...
#    id bin_1 bin_2  nom_0  ord_2_0  ord_2_1
# 0   0     F     N    Red        0        1
# 1   1     F     Y   Blue        1        0
# 2   2     F     N   Blue        1        1
# 3   3     F     N  Green        1        0
# 4   4     T     N    Red        1        1
# 5   5     T     N  Green        0        1
# 6   6     F     N    Red        1        1
# 7   7     T     N    Red        1        1
# 8   8     F     N   Blue        1        0
# 9   9     F     Y    Red        0        1

# %% [markdown]
# HASH ENCODING

# %%
from sklearn.feature_extraction import FeatureHasher
df=pd.read_csv(csv_url)
# n_features contains the number of bits you want in your hash value.
h = FeatureHasher(n_features = 3, input_type ='string')
# transforming the column after fitting
# The input to FeatureHasher must be an iterable of iterables of strings.
# We convert each string in 'nom_0' into a list containing that string.
hashed_Feature = h.fit_transform(df['nom_0'].apply(lambda x: [x]))
hashed_Feature = hashed_Feature.toarray()
df = pd.concat([df, pd.DataFrame(hashed_Feature)], axis = 1)
df.head(10)
# Out:
#    id bin_1 bin_2  nom_0 ord_2    0    1    2
# 0   0     F     N    Red   Hot  0.0  0.0  1.0
# 1   1     F     Y   Blue  Warm -1.0  0.0  0.0
# 2   2     F     N   Blue  Cold -1.0  0.0  0.0
# 3   3     F     N  Green  Warm  0.0  1.0  0.0
# 4   4     T     N    Red  Cold  0.0  0.0  1.0
# 5   5     T     N  Green   Hot  0.0  1.0  0.0
# 6   6     F     N    Red  Cold  0.0  0.0  1.0
# 7   7     T     N    Red  Cold  0.0  0.0  1.0
# 8   8     F     N   Blue  Warm -1.0  0.0  0.0
# 9   9     F     Y    Red   Hot  0.0  0.0  1.0

# %% [markdown]
# Mean/Target Encoding:

# %%
# inserting Target column in the dataset since it needs a target
df  = pd.read_csv(csv_url)
df.insert(5, "Target", [0, 1, 1, 0, 0, 1, 0, 0, 0, 1], True)
# importing TargetEncoder
from category_encoders import TargetEncoder
Targetenc = TargetEncoder()
# transforming the column after fitting
values = Targetenc.fit_transform(X = df.nom_0, y = df.Target)
# concatenating values with dataframe
df = pd.concat([df, values], axis = 1)
df.head(10)
# Out:
#    id bin_1 bin_2  nom_0 ord_2  Target     nom_0
# 0   0     F     N    Red   Hot       0  0.363515
# 1   1     F     Y   Blue  Warm       1  0.441191
# 2   2     F     N   Blue  Cold       1  0.441191
# 3   3     F     N  Green  Warm       0  0.414185
# 4   4     T     N    Red  Cold       0  0.363515
# 5   5     T     N  Green   Hot       1  0.414185
# 6   6     F     N    Red  Cold       0  0.363515
# 7   7     T     N    Red  Cold       0  0.363515
# 8   8     F     N   Blue  Warm       0  0.441191
# 9   9     F     Y    Red   Hot       1  0.363515

# %%
# !echo "# Enconding-techniques" >> README.md
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/bsiima/Enconding-techniques.git
# !git push -u origin main
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@2c2696ca614e.(none)')
# error: src refspec main does not match any
# ...

# %%
# !git config --global user.email "nuwabrenda@gmail.com"

# %%
# !git config --global user.name "bsiima"

# %%
# !echo "# Enconding-techniques" >> README.md
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/bsiima/Enconding-techniques.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/.git/
# [main (root-commit) 0ef9545] first commit
#  1 file changed, 2 insertions(+)
#  create mode 100644 README.md
# error: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# This line often causes 'error: remote origin already exists.' if run multiple times.
# It's only needed once to establish the remote connection.
# If you've run it before and it succeeded, you can comment it out.
# !git remote add origin https://github.com/bsiima/Enconding-techniques.git

# Ensure your main branch is set
# !git branch -M main

# Import userdata to access Colab secrets
from google.colab import userdata

# Retrieve your GitHub Personal Access Token (PAT) from Colab secrets
GH_TOKEN = userdata.get('GH_TOKEN')

# Use the PAT to authenticate the push operation
# The format is https://<PAT>@github.com/user/repo.git
# !git push https://{GH_TOKEN}@github.com/bsiima/Enconding-techniques.git main
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-468072514.py in <cell line: 0>()
#      11
#      12 # Retrieve your GitHub Personal Access Token (PAT) from Colab secrets
# ---> 13 GH_TOKEN = userdata.get('GH_TOKEN')
#      14
#      15 # Use the PAT to authenticate the push operation
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret GH_TOKEN does not exist.
